# %% [markdown]
# # Инициализация

# %%
from interpolation import *

# %%
styles = {
    0: {
        'color': 'blue',
        'linestyle': '-',
    },
    1: {
        'color': 'green',
        'linestyle': '--',
    },
    2: {
        'color': 'red',
        'linestyle': ':',
    },
    3:{
        'color': 'purple',
        'linestyle': '-.',
    }
}

# %%
itr = Interpolator()
points = [
    (0.172, -7.057),
    (0.567, -5.703),
    (1.113, -0.132),
    (2.119, 1.423),
    (2.796, 2.832)
]
x = np.arange(0.172, 2.796 + 0.5, 0.1)
itr.load_points(points)
graphic = lambda X, Y, names: itr.show_graph(X, Y, names, styles = styles)

# %% [markdown]
# ## Полином Лагранжа

# %%
lagrange_view, lagrange_func = itr.build_lagrange()
print(lagrange_view)
l_y = [lagrange_func(x) for x in x]
graphic(x, [l_y], ["Полином Лагранжа"])
# Out:
# L4(x)=
# -3.7162*(x - 0.567)*(x - 1.113)*(x - 2.119)*(x - 2.796)
# +7.6438*(x - 0.172)*(x - 1.113)*(x - 2.119)*(x - 2.796)
# +-0.1517*(x - 0.172)*(x - 0.567)*(x - 2.119)*(x - 2.796)
# +-0.6914*(x - 0.172)*(x - 0.567)*(x - 1.113)*(x - 2.796)
# +0.425*(x - 0.172)*(x - 0.567)*(x - 1.113)*(x - 2.119)

# %% [markdown]
# ## Конечные и разделенные разности

# %%
itr.show_final_diffs(4)
# Out:
# +-------------------------------------------+
# |         Таблица конечных разностей        |
# +--------+-------+--------+--------+--------+
# |   0    |   1   |   2    |   3    |   4    |
# +--------+-------+--------+--------+--------+
# | -7.057 | 1.354 | 4.217  | -8.233 | 12.103 |
# | -5.703 | 5.571 | -4.016 |  3.87  |  0.0   |
# | -0.132 | 1.555 | -0.146 |  0.0   |  0.0   |
# | 1.423  | 1.409 |  0.0   |  0.0   |  0.0   |
# | 2.832  |  0.0  |  0.0   |  0.0   |  0.0   |
# +--------+-------+--------+--------+--------+

# %%
itr.show_divided_diffs(4)
# Out:
# +-----------------------------------------------+
# |         Таблица разделенных разностей         |
# +--------+---------+---------+---------+--------+
# |   0    |    1    |    2    |    3    |   4    |
# +--------+---------+---------+---------+--------+
# | -7.057 |  3.4278 |  7.2003 | -6.5633 | 3.5094 |
# | -5.703 | 10.2033 | -5.5784 |  2.6454 |  0.0   |
# | -0.132 |  1.5457 |  0.3182 |   0.0   |  0.0   |
# | 1.423  |  2.0812 |   0.0   |   0.0   |  0.0   |
# | 2.832  |   0.0   |   0.0   |   0.0   |  0.0   |
# +--------+---------+---------+---------+--------+

# %% [markdown]
# ## Полином Ньютона

# %%
newton_view, newton_func = itr.build_newton()
print(newton_view)
n_y = [newton_func(x) for x in x]
graphic(x, [n_y], ["Полином Ньютона"])
# Out:
# N4(x)=
# -7.057
# +3.4278(x - 0.172)
# +7.2003(x - 0.172)*(x - 0.567)
# +-6.5633(x - 0.172)*(x - 0.567)*(x - 1.113)
# +3.5094(x - 0.172)*(x - 0.567)*(x - 1.113)*(x - 2.119)

# %% [markdown]
# ## Линейный сплайн

# %%
view, lin_spline_func = itr.build_linear_spline()
print(view)
ls_y = [lin_spline_func(x) for x in x]
graphic(x, [ls_y], ["Линейный сплайн"])
# Out:
# F(x)=
# 3.4278x + -7.6466, 0.172 <= x <= 0.567
# 10.2033x + -11.4883, 0.567 <= x <= 1.113
# 1.5457x + -1.8524, 1.113 <= x <= 2.119
# 2.0812x + -2.9871, 2.119 <= x <= 2.796
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 3
#       1 view, lin_spline_func = itr.build_linear_spline()
#       2 print(view)
# ----> 3 ls_y = [lin_spline_func(x) for x in x]
#       4 graphic(x, [ls_y], ["Линейный сплайн"])
#
# Cell In[8], line 3, in <listcomp>(.0)
#       1 view, lin_spline_func = itr.build_linear_spline()
#       2 print(view)
# ----> 3 ls_y = [lin_spline_func(x) for x in x]
#       4 graphic(x, [ls_y], ["Линейный сплайн"])
#
# File ~\OneDrive\Рабочий стол\numerical-methods-24\lab5\interpolation.py:144, in Interpolator.build_linear_spline.<locals>.<lambda>(x)
#     134     view.append(
#     135         f"{a}x + {b}, {x0} <= x <= {x1}",
#     136     )
#     138     self.conditions_set.append([
#     139         {'coefs': [a, b], 'bounds': [x0, x1]},
#     140         lambda x, x0, x1: x0 <= x <= x1,
#     141         lambda x, a, b: a*x + b
#     142     ])
# --> 144 return "\n".join(view), lambda x: self.fspline(x, self.conditions_set)
#
# File ~\OneDrive\Рабочий стол\numerical-methods-24\lab5\interpolation.py:13, in Interpolator.__init__.<locals>.<lambda>(x, conditions_set)
#      11 self.biases = []
#      12 self.conditions_set = []
# ---> 13 self.fspline = lambda x, conditions_set: [func(x, *c['coefs']) for c, cond, func in conditions_set if cond(x, *c['bounds'])][0]
#      14 self.final_diffs = {}
#      15 self.divided_diffs = {}
#
# IndexError: list index out of range

# %% [markdown]
# ## Квадратичный сплайн

# %%
view, quad_spline_func = itr.build_quadratic_spline()
print(view)
qs_y = [quad_spline_func(x) for x in x]
graphic(x, [qs_y], ["Квадратичный сплайн"])

# %% [markdown]
# ## Графики

# %%
graphic(
    x,
    [l_y, n_y, ls_y, qs_y],
    ["Полином Лагранжа", "Полином Ньютона", "Линейный сплайн", "Квадратичный сплайн"]
)
